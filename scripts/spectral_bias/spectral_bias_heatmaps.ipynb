# %% [markdown]
# ### Heatmap plots

# %% [markdown]
# Imports

# %%
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import random
import torch.nn as nn
import torch.optim as optim
import heapq
import os
from datetime import datetime
import argparse
import torch.nn.functional as F

# %% [markdown]
# Set save to True if you want to save plots

# %%
save = False

# %% [markdown]
# Only for python script: uncomment if running on cluster

# %%
# These are both placeholders
num_epochs = 1000
model_name = 'f0'

# %%
# # Parse command-line arguments
# parser = argparse.ArgumentParser(description='Train a neural network model')
# parser.add_argument('--epochs', type=int, default=1000, help='Number of training epochs')
# parser.add_argument('--model_name', type=str, default='model', help='Name of the saved model')
# args = parser.parse_args()

# # Use the parsed arguments
# num_epochs = args.epochs
# model_name = args.model_name

# %% [markdown]
# Check if CUDA is available

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
# For reproducibility
seed = 42

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(seed)

# %% [markdown]
# **Simplified function generation**

# %%
def generate_freq_dataset(num_samples, num_points, min_freq, max_freq):
    x = torch.linspace(0, 2 * np.pi, num_points, requires_grad=True)
    functions = []
    derivatives = []
    
    for _ in range(num_samples):
        num_freqs = torch.randint(min_freq, max_freq * 2, (1,)).item()
        amplitudes = torch.rand(num_freqs * 2)  # Double the number of amplitudes
        frequencies = torch.randint(min_freq, max_freq + 1, (num_freqs,)).float()
        phases = torch.rand(num_freqs * 2) * 2 * np.pi  # Double the number of phases
        
        y = sum(a * torch.sin(f * x + p) for a, f, p in zip(amplitudes[:num_freqs], frequencies, phases[:num_freqs])) + \
            sum(a * torch.cos(f * x + p) for a, f, p in zip(amplitudes[num_freqs:], frequencies, phases[num_freqs:]))
        
        dy_dx = torch.autograd.grad(y, x, grad_outputs=torch.ones_like(y), create_graph=True)[0]
        
        functions.append(y.detach().numpy())
        derivatives.append(dy_dx.detach().numpy())
    
    return np.array(functions), np.array(derivatives)

# %% [markdown]
# ## Generate datasets

# %%
num_samples = 500
num_points = 1000
batch_size = 32

low_freq_functions, low_freq_derivatives = generate_freq_dataset(num_samples, num_points, 1, 5)
general_freq_functions, general_freq_derivatives = generate_freq_dataset(num_samples, num_points, 1, 15)
high_freq_functions, high_freq_derivatives = generate_freq_dataset(num_samples, num_points, 10, 15)

low_freq_dataset = TensorDataset(torch.tensor(low_freq_functions), torch.tensor(low_freq_derivatives))
general_freq_dataset = TensorDataset(torch.tensor(general_freq_functions), torch.tensor(general_freq_derivatives))
high_freq_dataset = TensorDataset(torch.tensor(high_freq_functions), torch.tensor(high_freq_derivatives))

low_freq_dataloader = DataLoader(TensorDataset(torch.tensor(low_freq_functions), torch.tensor(low_freq_derivatives)), batch_size=batch_size, shuffle=True)
high_freq_dataloader = DataLoader(TensorDataset(torch.tensor(high_freq_functions), torch.tensor(high_freq_derivatives)), batch_size=batch_size, shuffle=True)
general_freq_dataloader = DataLoader(TensorDataset(torch.tensor(general_freq_functions), torch.tensor(general_freq_derivatives)), batch_size=batch_size, shuffle=True)

# %%
total_size = len(low_freq_dataset)
train_size = int(0.8 * total_size)
test_size = total_size - train_size
generator = torch.Generator().manual_seed(seed)

# low freq
train_dataset_l, test_dataset_l = random_split(low_freq_dataset, [train_size, test_size], generator=generator)
train_dataloader_l = DataLoader(train_dataset_l, batch_size=32, shuffle=True, drop_last=True)
test_dataloader_l = DataLoader(test_dataset_l, batch_size=32, shuffle=False, drop_last=True)

# general freq
train_dataset_g, test_dataset_g = random_split(general_freq_dataset, [train_size, test_size], generator=generator)
train_dataloader_g = DataLoader(train_dataset_g, batch_size=32, shuffle=True, drop_last=True)
test_dataloader_g = DataLoader(test_dataset_g, batch_size=32, shuffle=False, drop_last=True)

# high freq
train_dataset_h, test_dataset_h = random_split(high_freq_dataset, [train_size, test_size], generator=generator)
train_dataloader_h = DataLoader(train_dataset_h, batch_size=32, shuffle=True, drop_last=True)
test_dataloader_h = DataLoader(test_dataset_h, batch_size=32, shuffle=False, drop_last=True)

# %% [markdown]
# ## Plot random function from one of the datasets

# %%
a = np.random.randint(32)

fun, deriv = next(iter(low_freq_dataloader))

first_function = fun[a]
first_derivative = deriv[a]

# Generate x values corresponding to the function inputs
x_values = np.linspace(0, 2 * np.pi, 1000)

# Plotting the function and its derivative
plt.figure(figsize=(10, 6))
plt.plot(x_values, first_function, label='Function')
plt.plot(x_values, first_derivative, label='Derivative')
plt.title('Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Save datasets
# torch.save(general_freq_dataset, 'datasets/general_freq_dataset.pt')
# torch.save(low_freq_dataset, 'datasets/low_freq_dataset.pt')
# torch.save(high_freq_dataset, 'datasets/high_freq_dataset.pt')

# %% [markdown]
# Stopped here

# %% [markdown]
# ## Model architecture

# %% [markdown]
# This CNN uses 3 layers, each with kernel size 3

# %%
# simple 1D CNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv1d(1, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv1d(64, 1, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.conv3(x)
        return x

# %%
f0 = SimpleCNN()
criterion = nn.MSELoss()

# %% [markdown]
# ## Miscellaneous plotting functions

# %%
def plot_losses(train_losses, test_losses, save_dir='plots', filename=None, save=False):
    if not train_losses:
        return
    
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    current_date = datetime.now().strftime("%m-%d")
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_losses, linestyle='-', color='b', label='Training Loss')
    plt.plot(epochs, test_losses, linestyle='-', label='Test Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.yscale('log')  # Set the y-axis to logarithmic scale
    plt.legend()
    plt.grid(True)
    filename = f"{filename}_{current_date}.png"
    save_path = os.path.join(save_dir, filename)
    if save:
        plt.savefig(save_path)    
    plt.show()

# %%
def plot_output(model1, dataset, order=None, save_dir='plots', filename=None, save=False): 
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    current_date = datetime.now().strftime("%m-%d")
    model1.eval()  # Set the model to evaluation mode

    train_dataloader_viz = get_random_function(dataset, shuffle=True)
    # Get a random sample from the dataloader
    dataiter = iter(train_dataloader_viz)
    function, true_derivative = next(dataiter)

    # Reshape the input for the model
    function = function.unsqueeze(1)  # Add channel dimension

    # Make prediction
    with torch.no_grad():
        if order == 1 or order == 2:
            predicted_derivative = model1(function)
        
        if order == 'rollout':
            predicted_derivative = model1(function)
            predicted_derivative = model1(predicted_derivative)

    # Convert tensors to numpy arrays for plotting
    x = torch.linspace(0, 2*torch.pi, 1000).numpy()
    function = function.squeeze().numpy()

    predicted_derivative = predicted_derivative.squeeze().numpy()

    true_derivative = true_derivative.squeeze().numpy()

    # Plot the results
    plt.figure(figsize=(12, 6))

    plt.plot(x, function, label='Original Function', color='blue')
    if order == 1:
        plt.plot(x, true_derivative, label=f'True {order}st derivative')

    plt.plot(x[10:-10], predicted_derivative[10:-10], label=f'Predicted {order}nd Derivative', linestyle='--')

    plt.title('Function, True Derivatives, and Predicted Derivatives')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    filename = f"{filename}_{current_date}.png"

    save_path = os.path.join(save_dir, filename)
    if save:
        plt.savefig(save_path)  
    plt.show()

# %%
def get_random_function(dataset, shuffle=True):
    return DataLoader(dataset, batch_size=1, shuffle=shuffle)

# %% [markdown]
# ## Function to train model

# %%
train_losses, test_losses = [], []

def model_training(model, train_dataloader, test_dataloader, num_epochs,\
    split_freq=None, filename=None, save=None, order=None):
    train_losses = []
    test_losses = []

    low_freq_nmses = []
    general_freq_nmses = []
    high_freq_nmses = []
    epoch_list = []

    lr = 1e-3

    optimizer = optim.Adam(model.parameters(), lr=lr)

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        test_loss = 0.0

        if epoch % split_freq == 0:
            l, g, h = print_and_store_metrics(model)
            low_freq_nmses.append(l)
            general_freq_nmses.append(g)
            high_freq_nmses.append(h)
            epoch_list.append(epoch)

        for batch_functions, batch_derivatives in train_dataloader:
            batch_functions = batch_functions.unsqueeze(1)
            batch_derivatives = batch_derivatives.unsqueeze(1)

            outputs = model(batch_functions)
            loss = criterion(outputs, batch_derivatives)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_dataloader)

        model.eval()
        with torch.no_grad():
            for b_test_functions, b_test_derivatives in test_dataloader:
                b_test_functions = b_test_functions.unsqueeze(1)
                b_test_derivatives = b_test_derivatives.unsqueeze(1)

                test_outputs = model(b_test_functions)
                batch_test_loss = criterion(test_outputs, b_test_derivatives)

                test_loss += batch_test_loss.item()

        test_loss /= len(test_dataloader)

        train_losses.append(train_loss)
        test_losses.append(test_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}')

    print(f"Training finished for {order}st derivative")

    plt.figure(figsize=(10, 6))
    plt.plot(epoch_list, low_freq_nmses, label='Low freq NMSE')
    plt.plot(epoch_list, general_freq_nmses, label='General freq NMSE')
    plt.plot(epoch_list, high_freq_nmses, label='High freq NMSE')

    # Adding labels and title
    plt.xlabel('Epoch')
    plt.ylabel('NMSE')
    plt.title('NMSEs of different frequencies during training')
    plt.legend()

    # Show the plot
    plt.grid(True)
    plt.show()
    if save:
        plt.savefig(filename)  

    return train_losses, test_losses

# %% [markdown]
# ## Metric functions

# %%
def compute_mse(dataloader, model):
    """
    Takes in a dataloader and a model to compute MSE.
    """

    model.eval()
    all_outputs = []
    all_targets = []

    for function, deriv in dataloader:
        function = function.unsqueeze(1)
        deriv = deriv.unsqueeze(1)

        # Compute model output
        model_output = model(function)
        all_targets.append(deriv)

        # Collect outputs
        all_outputs.append(model_output)

    # Concatenate all collected outputs and targets
    all_outputs = torch.cat(all_outputs, dim=0)
    all_targets = torch.cat(all_targets, dim=0)

    # Compute MSE
    mse = torch.mean((all_targets - all_outputs) ** 2)
    nmse = mse / torch.mean(all_targets ** 2)

    return mse.item(), nmse.item()

criterion = torch.nn.MSELoss()

# %%
def print_and_store_metrics(f0):
    return compute_mse(train_dataloader_l, f0)[1], compute_mse(train_dataloader_g, f0)[1], compute_mse(train_dataloader_h, f0)[1]

# %%
def print_metrics(model):
    print(f"NMSE over low freq test functions: {compute_mse(test_dataloader_l, model)[1]}")
    print(f"NMSE over general freq test functions: {compute_mse(test_dataloader_g, model)[1]}")
    print(f"NMSE over high freq test functions: {compute_mse(test_dataloader_h, model)[1]}")

# %% [markdown]
# ## Create models

# %%
# simple 1D CNN
class SimpleCNN(nn.Module):
    def __init__(self, n_layers=3, kernel_size=3, hidden_size=64):
        super(SimpleCNN, self).__init__()
        # Parameters
        self.n_layers = n_layers
        self.kernel_size = kernel_size
        self.hidden_size = hidden_size

        # Model
        self.convs = nn.ModuleList()
        if n_layers == 1:
            self.convs.append(nn.Conv1d(1, 1, kernel_size=kernel_size, padding=kernel_size//2))
        elif n_layers >= 2:
            self.convs.append(nn.Conv1d(1, hidden_size, kernel_size=kernel_size, padding=kernel_size//2))
            for _ in range(n_layers - 2):
                self.convs.append(nn.Conv1d(hidden_size, hidden_size, kernel_size=kernel_size, padding=kernel_size//2))
            self.convs.append(nn.Conv1d(hidden_size, 1, kernel_size=kernel_size, padding=kernel_size//2))
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

    def forward(self, x):
        for i, conv in enumerate(self.convs):
            if i < len(self.convs) - 1:
                x = self.relu(conv(x))
            else:
                x = conv(x)
        return x

# %%
set_seed(seed)
L3ModelK3 = SimpleCNN(n_layers=3, kernel_size=3)

# %%
# train_losses, test_losses = model_training(L3ModelK3, train_dataloader_g, test_dataloader_g,\
#     num_epochs=1000, split_freq=10, filename='../plots/spectral_bias/f0_E2000_phased_training',\
#     save=save, order='first')
# plot_losses(train_losses, test_losses, save_dir='../plots/spectral_bias', filename='f0_E2000_phased_training', save=save)

# %% [markdown]
# ## Plot results

# %%
def plot_all_outputs(model, model_name):
    plot_output(model, dataset=test_dataset_l, order=1, save_dir='../plots/spectral_bias', filename=f'{model_name}_E{num_epochs}_lf_output', save=save)
    plot_output(model, dataset=test_dataset_g, order=1, save_dir='../plots/spectral_bias', filename=f'{model_name}_E{num_epochs}_lf_output', save=save)
    plot_output(model, dataset=test_dataset_h, order=1, save_dir='../plots/spectral_bias', filename=f'{model_name}_E{num_epochs}_lf_output', save=save)

# %%
plot_all_outputs(L3ModelK3, model_name = 'L3ModelK3')

# %%
print_metrics(L3ModelK3)
# Out:
# NMSE over low freq test functions: 0.9994839429855347
# NMSE over general freq test functions: 0.9994645118713379
# NMSE over high freq test functions: 0.9995222091674805

# %%
print(L3ModelK3)
# Out:
# SimpleCNN(
#   (convs): ModuleList(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (2): Conv1d(64, 1, kernel_size=(3,), stride=(1,), padding=(1,))
#   )
#   (relu): ReLU()
#   (tanh): Tanh()
# )

# %% [markdown]
# **3 layer model with kernel size 9**

# %%
set_seed(seed)
L3ModelK9 = SimpleCNN(n_layers=3, kernel_size=9)

# %%
# train_losses, test_losses = model_training(L3ModelK9, train_dataloader_g, test_dataloader_g,\
#     num_epochs=1000, split_freq=10, filename='../plots/spectral_bias/f0_E2000_phased_training',\
#     save=save, order='first')
# plot_losses(train_losses, test_losses, save_dir='../plots/spectral_bias', filename='f0_E2000_phased_training', save=save)

# %%
plot_all_outputs(L3ModelK9, model_name='L3ModelK9')

# %%
print_metrics(L3ModelK9)
print(L3ModelK9)
# Out:
# NMSE over low freq test functions: 0.9949268102645874
# NMSE over general freq test functions: 0.9951961636543274
# NMSE over high freq test functions: 0.9954105019569397
# SimpleCNN(
#   (convs): ModuleList(
#     (0): Conv1d(1, 64, kernel_size=(9,), stride=(1,), padding=(4,))
#     (1): Conv1d(64, 64, kernel_size=(9,), stride=(1,), padding=(4,))
#     (2): Conv1d(64, 1, kernel_size=(9,), stride=(1,), padding=(4,))
#   )
#   (relu): ReLU()
#   (tanh): Tanh()
# )

# %% [markdown]
# **3 layer model with kernel size 12**

# %%
set_seed(seed)
L3ModelK15 = SimpleCNN(n_layers=3, kernel_size=15)
plot_all_outputs(L3ModelK15, model_name='L3ModelK15')

# %% [markdown]
# ## Trying to create the colormap

# %% [markdown]
# **Correct version with dataloader as input**

# %%
def compute_fft_and_max_freq(dataloader, compute_output=False, model=None):
    fft_amplitudes = []
    max_frequencies = []
    T = 2 * torch.pi
    N = 1000

    # Calculate frequencies for the FFT
    frequencies = torch.fft.fftfreq(N, T / (2 * torch.pi * N))
    positive_freq_indices = frequencies >= 0
    positive_freqs = frequencies[positive_freq_indices]

    # Iterate over each batch
    for functions, _ in dataloader:  # Note that derivatives are ignored in this loop
        
        if compute_output:
            functions = model(functions.unsqueeze(1)).squeeze()
            # output = model(functions)
            
            # output = output.squeeze()
            # functions = output # set this so that the FFTs can be computed in the next line
        
        # Compute FFT using PyTorch
        F = torch.fft.fft(functions)
        magnitudes = torch.abs(F) / N

        # Consider only positive frequencies
        positive_magnitudes = magnitudes[:, positive_freq_indices]

        fft_amplitudes.append(positive_magnitudes)
        
        # Maximum frequency based on the highest amplitude for each function in the batch
        max_indices = torch.argmax(positive_magnitudes, dim=1)
        batch_max_freqs = positive_freqs[max_indices]
        max_frequencies.extend(batch_max_freqs)

    return torch.vstack(fft_amplitudes), torch.tensor(max_frequencies), positive_freqs

def plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type, xmin=0, xmax=0):
    fft_amplitudes = fft_amplitudes.detach().numpy()
    max_frequencies = max_frequencies.detach().numpy()
    freqs = freqs.detach().numpy()
    
    # Sort functions by the maximum frequency
    sorted_indices = np.argsort(-max_frequencies)  # Sort in descending order
    sorted_fft = fft_amplitudes[sorted_indices]

    plt.figure(figsize=(10, 6))
    im = plt.imshow(sorted_fft, aspect='auto', extent=[freqs[0], freqs[-1], 0, len(sorted_fft)])
    plt.colorbar(im, label='Amplitude')
    plt.xlabel('Frequency (rad/s)')
    plt.ylabel('Function Index (sorted by max frequency)')
    plt.title(f'FFT Amplitude Heatmap for {fun_type}')
    plt.xlim([xmin, xmax])
    plt.show()

# %%
def plot_heatmaps(model):
    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_dataloader,\
        compute_output=True, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Low freq model outputs', xmin=0, xmax=6)

    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(general_freq_dataloader,\
        compute_output=True, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='General freq model outputs', xmin=0, xmax=16)

    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(high_freq_dataloader,\
        compute_output=True, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='High freq model outputs', xmin=10, xmax=16)

# %%
fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_dataloader)
plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Function', xmin=0, xmax=6)

# %% [markdown]
# ### Heatmap for low frequency dataset

# %%
# fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_functions)
# plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Function', xmin=0, xmax=6)
# # Note: we should let xlim = max_freq + 1 since the FFT calculates positive frequency past the peak
# # i.e., the frequency will only go to 0 at x=6 for sin(5x)

# %% [markdown]
# ### Heatmap for general frequencies

# %%
fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(general_freq_dataloader)
plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Function', xmin=0, xmax=16)

# %% [markdown]
# ### Heatmap for derivatives

# %% [markdown]
# ### Heatmap for high frequencies

# %%
fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(high_freq_dataloader)
plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='high freq function', xmin=10, xmax=16)

# %% [markdown]
# ## Frequencies of model outputs

# %%
fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(general_freq_dataloader,\
    compute_output=True, model=L3ModelK15)
plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Model outputs', xmin=0, xmax=16)

# %%
fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_dataloader,\
    compute_output=True, model=L3ModelK15)
plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Model outputs', xmin=0, xmax=6)

# %%
print(compute_mse(train_dataloader_l, L3ModelK15)[1])
# Out:
# 1.0060957670211792

# %% [markdown]
# ## Trained model: 3 layers, kernel size 9

# %%
set_seed(seed)
L3ModelK9_trained = SimpleCNN(n_layers=3, kernel_size=3)

train_losses, test_losses = model_training(L3ModelK9_trained, train_dataloader_g, test_dataloader_g,\
    num_epochs=500, split_freq=10, filename='../plots/spectral_bias/f0_E2000_phased_training',\
    save=save, order='first')
plot_losses(train_losses, test_losses, save_dir='../plots/spectral_bias', filename='f0_E2000_phased_training', save=save)
# Out:
# Epoch [1/500], Train Loss: 440.8359, Test Loss: 364.8578
# Epoch [2/500], Train Loss: 420.8708, Test Loss: 347.7103
# Epoch [3/500], Train Loss: 397.4329, Test Loss: 316.2268
# Epoch [4/500], Train Loss: 344.7371, Test Loss: 267.0506
# Epoch [5/500], Train Loss: 280.6145, Test Loss: 199.2646
# Epoch [6/500], Train Loss: 195.8094, Test Loss: 120.8080
# Epoch [7/500], Train Loss: 104.3812, Test Loss: 55.0706
# Epoch [8/500], Train Loss: 42.6102, Test Loss: 19.3664
# Epoch [9/500], Train Loss: 18.3718, Test Loss: 12.4382
# Epoch [10/500], Train Loss: 15.0311, Test Loss: 12.0920
# Epoch [11/500], Train Loss: 14.3873, Test Loss: 11.2176
# Epoch [12/500], Train Loss: 13.8658, Test Loss: 10.8709
# Epoch [13/500], Train Loss: 13.1750, Test Loss: 10.5248
# Epoch [14/500], Train Loss: 12.8816, Test Loss: 10.2105
# Epoch [15/500], Train Loss: 12.6597, Test Loss: 9.9416
# Epoch [16/500], Train Loss: 12.1188, Test Loss: 9.6594
# Epoch [17/500], Train Loss: 11.7766, Test Loss: 9.4239
# Epoch [18/500], Train Loss: 11.3002, Test Loss: 9.1394
# Epoch [19/500], Train Loss: 10.8590, Test Loss: 8.8754
# Epoch [20/500], Train Loss: 10.4417, Test Loss: 8.5993
# Epoch [21/500], Train Loss: 10.4374, Test Loss: 8.3420
# Epoch [22/500], Train Loss: 9.8120, Test Loss: 8.0801
# Epoch [23/500], Train Loss: 9.4899, Test Loss: 7.8423
# Epoch [24/500], Train Loss: 9.4232, Test Loss: 7.5873
# Epoch [25/500], Train Loss: 8.8255, Test Loss: 7.3793
# Epoch [26/500], Train Loss: 8.6502, Test Loss: 7.0933
# Epoch [27/500], Train Loss: 8.2587, Test Loss: 6.8644
# Epoch [28/500], Train Loss: 7.9631, Test Loss: 6.6730
# Epoch [29/500], Train Loss: 7.7064, Test Loss: 6.4315
# Epoch [30/500], Train Loss: 7.3967, Test Loss: 6.2191
# Epoch [31/500], Train Loss: 7.0686, Test Loss: 6.0332
# Epoch [32/500], Train Loss: 7.0654, Test Loss: 6.0599
# Epoch [33/500], Train Loss: 6.8299, Test Loss: 5.7995
# Epoch [34/500], Train Loss: 6.6325, Test Loss: 5.8026
# Epoch [35/500], Train Loss: 6.4111, Test Loss: 5.4644
# Epoch [36/500], Train Loss: 6.1943, Test Loss: 5.2543
# Epoch [37/500], Train Loss: 5.9254, Test Loss: 5.0656
# Epoch [38/500], Train Loss: 5.6521, Test Loss: 4.8857
# Epoch [39/500], Train Loss: 5.4816, Test Loss: 4.7360
# Epoch [40/500], Train Loss: 5.1923, Test Loss: 4.6188
# Epoch [41/500], Train Loss: 5.1072, Test Loss: 4.4877
# Epoch [42/500], Train Loss: 5.0612, Test Loss: 4.3718
# Epoch [43/500], Train Loss: 4.7778, Test Loss: 4.2573
# Epoch [44/500], Train Loss: 4.7175, Test Loss: 4.1553
# Epoch [45/500], Train Loss: 4.5814, Test Loss: 4.0912
# Epoch [46/500], Train Loss: 4.4698, Test Loss: 3.9545
# Epoch [47/500], Train Loss: 4.3149, Test Loss: 3.8289
# Epoch [48/500], Train Loss: 4.2279, Test Loss: 3.7329
# Epoch [49/500], Train Loss: 4.1214, Test Loss: 3.6493
# Epoch [50/500], Train Loss: 3.9629, Test Loss: 3.6073
# Epoch [51/500], Train Loss: 3.9119, Test Loss: 3.4961
# Epoch [52/500], Train Loss: 3.8095, Test Loss: 3.3800
# Epoch [53/500], Train Loss: 3.6561, Test Loss: 3.3172
# Epoch [54/500], Train Loss: 3.5274, Test Loss: 3.2344
# Epoch [55/500], Train Loss: 3.4851, Test Loss: 3.1617
# Epoch [56/500], Train Loss: 3.3725, Test Loss: 3.0843
# Epoch [57/500], Train Loss: 3.2767, Test Loss: 3.0260
# Epoch [58/500], Train Loss: 3.2481, Test Loss: 2.9723
# Epoch [59/500], Train Loss: 3.1344, Test Loss: 2.9495
# Epoch [60/500], Train Loss: 3.0678, Test Loss: 2.8228
# Epoch [61/500], Train Loss: 3.0048, Test Loss: 2.8126
# Epoch [62/500], Train Loss: 2.9684, Test Loss: 2.7248
# Epoch [63/500], Train Loss: 2.7959, Test Loss: 2.6729
# Epoch [64/500], Train Loss: 2.7812, Test Loss: 2.6221
# Epoch [65/500], Train Loss: 2.7396, Test Loss: 2.5766
# Epoch [66/500], Train Loss: 2.7509, Test Loss: 2.6310
# Epoch [67/500], Train Loss: 2.7214, Test Loss: 2.5733
# Epoch [68/500], Train Loss: 2.5568, Test Loss: 2.4801
# Epoch [69/500], Train Loss: 2.5096, Test Loss: 2.4213
# Epoch [70/500], Train Loss: 2.4472, Test Loss: 2.3888
# Epoch [71/500], Train Loss: 2.4282, Test Loss: 2.3311
# Epoch [72/500], Train Loss: 2.4477, Test Loss: 2.3223
# Epoch [73/500], Train Loss: 2.3890, Test Loss: 2.2419
# Epoch [74/500], Train Loss: 2.4406, Test Loss: 2.2297
# Epoch [75/500], Train Loss: 2.3124, Test Loss: 2.2168
# Epoch [76/500], Train Loss: 2.2578, Test Loss: 2.1965
# Epoch [77/500], Train Loss: 2.2279, Test Loss: 2.1597
# Epoch [78/500], Train Loss: 2.1721, Test Loss: 2.0829
# Epoch [79/500], Train Loss: 2.1290, Test Loss: 2.0460
# Epoch [80/500], Train Loss: 2.0814, Test Loss: 2.0153
# Epoch [81/500], Train Loss: 2.0597, Test Loss: 1.9787
# Epoch [82/500], Train Loss: 1.9584, Test Loss: 1.9521
# Epoch [83/500], Train Loss: 1.9464, Test Loss: 1.9330
# Epoch [84/500], Train Loss: 1.9606, Test Loss: 1.9115
# Epoch [85/500], Train Loss: 1.9240, Test Loss: 1.8863
# Epoch [86/500], Train Loss: 1.9122, Test Loss: 1.8926
# Epoch [87/500], Train Loss: 1.8723, Test Loss: 1.9722
# Epoch [88/500], Train Loss: 1.8654, Test Loss: 1.8469
# Epoch [89/500], Train Loss: 1.8194, Test Loss: 1.7981
# Epoch [90/500], Train Loss: 1.7861, Test Loss: 1.8041
# Epoch [91/500], Train Loss: 1.8087, Test Loss: 1.9411
# Epoch [92/500], Train Loss: 1.8119, Test Loss: 1.8379
# Epoch [93/500], Train Loss: 1.7347, Test Loss: 1.7625
# Epoch [94/500], Train Loss: 1.9427, Test Loss: 1.7834
# Epoch [95/500], Train Loss: 1.7228, Test Loss: 1.6447
# Epoch [96/500], Train Loss: 1.6195, Test Loss: 1.6387
# Epoch [97/500], Train Loss: 1.6198, Test Loss: 1.6207
# Epoch [98/500], Train Loss: 1.5930, Test Loss: 1.5887
# Epoch [99/500], Train Loss: 1.5406, Test Loss: 1.5772
# Epoch [100/500], Train Loss: 1.5143, Test Loss: 1.5513
# Epoch [101/500], Train Loss: 1.5122, Test Loss: 1.5381
# Epoch [102/500], Train Loss: 1.4782, Test Loss: 1.5312
# Epoch [103/500], Train Loss: 1.4834, Test Loss: 1.5027
# Epoch [104/500], Train Loss: 1.4644, Test Loss: 1.4813
# Epoch [105/500], Train Loss: 1.4382, Test Loss: 1.4789
# Epoch [106/500], Train Loss: 1.4249, Test Loss: 1.4472
# Epoch [107/500], Train Loss: 1.3864, Test Loss: 1.4452
# Epoch [108/500], Train Loss: 1.4116, Test Loss: 1.4321
# Epoch [109/500], Train Loss: 1.3841, Test Loss: 1.4135
# Epoch [110/500], Train Loss: 1.3320, Test Loss: 1.3979
# Epoch [111/500], Train Loss: 1.3336, Test Loss: 1.3795
# Epoch [112/500], Train Loss: 1.3774, Test Loss: 1.4521
# Epoch [113/500], Train Loss: 1.3821, Test Loss: 1.3901
# Epoch [114/500], Train Loss: 1.2885, Test Loss: 1.5031
# Epoch [115/500], Train Loss: 1.4136, Test Loss: 1.3233
# Epoch [116/500], Train Loss: 1.2894, Test Loss: 1.4377
# Epoch [117/500], Train Loss: 1.2860, Test Loss: 1.3109
# Epoch [118/500], Train Loss: 1.2482, Test Loss: 1.2798
# Epoch [119/500], Train Loss: 1.1975, Test Loss: 1.2756
# Epoch [120/500], Train Loss: 1.2278, Test Loss: 1.2475
# Epoch [121/500], Train Loss: 1.2066, Test Loss: 1.2441
# Epoch [122/500], Train Loss: 1.1877, Test Loss: 1.2146
# Epoch [123/500], Train Loss: 1.2674, Test Loss: 1.3183
# Epoch [124/500], Train Loss: 1.2972, Test Loss: 1.3018
# Epoch [125/500], Train Loss: 1.2305, Test Loss: 1.2418
# Epoch [126/500], Train Loss: 1.1773, Test Loss: 1.1811
# Epoch [127/500], Train Loss: 1.1105, Test Loss: 1.1683
# Epoch [128/500], Train Loss: 1.1263, Test Loss: 1.1412
# Epoch [129/500], Train Loss: 1.0554, Test Loss: 1.1357
# Epoch [130/500], Train Loss: 1.0538, Test Loss: 1.1254
# Epoch [131/500], Train Loss: 1.0618, Test Loss: 1.1108
# Epoch [132/500], Train Loss: 1.0398, Test Loss: 1.0992
# Epoch [133/500], Train Loss: 1.0781, Test Loss: 1.1277
# Epoch [134/500], Train Loss: 1.0403, Test Loss: 1.1474
# Epoch [135/500], Train Loss: 1.0486, Test Loss: 1.0978
# Epoch [136/500], Train Loss: 1.0272, Test Loss: 1.0669
# Epoch [137/500], Train Loss: 0.9939, Test Loss: 1.0517
# Epoch [138/500], Train Loss: 0.9863, Test Loss: 1.0473
# Epoch [139/500], Train Loss: 0.9678, Test Loss: 1.0448
# Epoch [140/500], Train Loss: 0.9747, Test Loss: 1.0401
# Epoch [141/500], Train Loss: 0.9846, Test Loss: 1.0098
# Epoch [142/500], Train Loss: 0.9374, Test Loss: 1.0020
# Epoch [143/500], Train Loss: 0.9361, Test Loss: 0.9988
# Epoch [144/500], Train Loss: 0.9326, Test Loss: 0.9798
# Epoch [145/500], Train Loss: 0.8975, Test Loss: 0.9745
# Epoch [146/500], Train Loss: 0.8957, Test Loss: 0.9795
# Epoch [147/500], Train Loss: 0.9112, Test Loss: 0.9877
# Epoch [148/500], Train Loss: 0.9053, Test Loss: 0.9472
# Epoch [149/500], Train Loss: 0.8723, Test Loss: 0.9394
# Epoch [150/500], Train Loss: 0.8929, Test Loss: 0.9496
# Epoch [151/500], Train Loss: 0.9057, Test Loss: 1.0660
# Epoch [152/500], Train Loss: 0.9346, Test Loss: 1.0340
# Epoch [153/500], Train Loss: 0.9525, Test Loss: 1.1272
# Epoch [154/500], Train Loss: 1.0075, Test Loss: 0.9038
# Epoch [155/500], Train Loss: 0.9155, Test Loss: 1.0757
# Epoch [156/500], Train Loss: 0.9352, Test Loss: 1.1153
# Epoch [157/500], Train Loss: 0.8930, Test Loss: 0.9505
# Epoch [158/500], Train Loss: 0.8399, Test Loss: 0.9102
# Epoch [159/500], Train Loss: 0.8218, Test Loss: 0.8689
# Epoch [160/500], Train Loss: 0.7716, Test Loss: 0.8886
# Epoch [161/500], Train Loss: 0.7999, Test Loss: 0.9102
# Epoch [162/500], Train Loss: 0.8076, Test Loss: 0.8488
# Epoch [163/500], Train Loss: 0.7679, Test Loss: 0.8523
# Epoch [164/500], Train Loss: 0.7823, Test Loss: 0.8472
# Epoch [165/500], Train Loss: 0.7786, Test Loss: 0.8336
# Epoch [166/500], Train Loss: 0.7835, Test Loss: 0.8361
# Epoch [167/500], Train Loss: 0.7592, Test Loss: 0.8241
# Epoch [168/500], Train Loss: 0.7654, Test Loss: 0.8190
# Epoch [169/500], Train Loss: 0.7678, Test Loss: 0.8196
# Epoch [170/500], Train Loss: 0.7344, Test Loss: 0.8255
# Epoch [171/500], Train Loss: 0.7138, Test Loss: 0.8452
# Epoch [172/500], Train Loss: 0.7597, Test Loss: 0.8768
# Epoch [173/500], Train Loss: 0.7846, Test Loss: 0.8056
# Epoch [174/500], Train Loss: 0.7480, Test Loss: 0.7841
# Epoch [175/500], Train Loss: 0.7139, Test Loss: 0.7827
# Epoch [176/500], Train Loss: 0.7035, Test Loss: 0.8238
# Epoch [177/500], Train Loss: 0.7015, Test Loss: 0.8078
# Epoch [178/500], Train Loss: 0.7317, Test Loss: 0.8399
# Epoch [179/500], Train Loss: 0.7032, Test Loss: 0.7653
# Epoch [180/500], Train Loss: 0.7081, Test Loss: 0.8885
# Epoch [181/500], Train Loss: 0.7493, Test Loss: 0.7789
# Epoch [182/500], Train Loss: 0.6790, Test Loss: 0.7607
# Epoch [183/500], Train Loss: 0.6738, Test Loss: 0.7506
# Epoch [184/500], Train Loss: 0.6726, Test Loss: 0.7438
# Epoch [185/500], Train Loss: 0.6735, Test Loss: 0.7366
# Epoch [186/500], Train Loss: 0.7266, Test Loss: 0.8171
# Epoch [187/500], Train Loss: 0.6684, Test Loss: 0.7329
# Epoch [188/500], Train Loss: 0.6603, Test Loss: 0.7297
# Epoch [189/500], Train Loss: 0.6661, Test Loss: 0.7634
# Epoch [190/500], Train Loss: 0.6864, Test Loss: 0.7369
# Epoch [191/500], Train Loss: 0.6729, Test Loss: 0.7832
# Epoch [192/500], Train Loss: 0.7070, Test Loss: 0.7346
# Epoch [193/500], Train Loss: 0.6527, Test Loss: 0.7282
# Epoch [194/500], Train Loss: 0.6653, Test Loss: 0.7183
# Epoch [195/500], Train Loss: 0.6843, Test Loss: 0.7123
# Epoch [196/500], Train Loss: 0.6517, Test Loss: 0.7005
# Epoch [197/500], Train Loss: 0.6243, Test Loss: 0.7068
# Epoch [198/500], Train Loss: 0.6284, Test Loss: 0.6917
# Epoch [199/500], Train Loss: 0.6254, Test Loss: 0.7284
# Epoch [200/500], Train Loss: 0.6155, Test Loss: 0.6817
# Epoch [201/500], Train Loss: 0.5945, Test Loss: 0.6734
# Epoch [202/500], Train Loss: 0.6393, Test Loss: 0.9898
# Epoch [203/500], Train Loss: 0.7173, Test Loss: 0.6837
# Epoch [204/500], Train Loss: 0.6823, Test Loss: 0.7763
# Epoch [205/500], Train Loss: 0.6920, Test Loss: 0.6884
# Epoch [206/500], Train Loss: 0.7479, Test Loss: 0.6675
# Epoch [207/500], Train Loss: 0.6410, Test Loss: 0.7443
# Epoch [208/500], Train Loss: 0.6173, Test Loss: 0.6889
# Epoch [209/500], Train Loss: 0.6249, Test Loss: 0.6549
# Epoch [210/500], Train Loss: 0.6049, Test Loss: 0.6948
# Epoch [211/500], Train Loss: 0.6103, Test Loss: 0.6379
# Epoch [212/500], Train Loss: 0.6102, Test Loss: 0.7240
# Epoch [213/500], Train Loss: 0.6780, Test Loss: 0.7793
# Epoch [214/500], Train Loss: 0.6006, Test Loss: 0.6320
# Epoch [215/500], Train Loss: 0.5674, Test Loss: 0.6412
# Epoch [216/500], Train Loss: 0.5650, Test Loss: 0.6467
# Epoch [217/500], Train Loss: 0.5518, Test Loss: 0.6326
# Epoch [218/500], Train Loss: 0.5554, Test Loss: 0.6509
# Epoch [219/500], Train Loss: 0.6865, Test Loss: 0.8213
# Epoch [220/500], Train Loss: 0.8790, Test Loss: 0.7559
# Epoch [221/500], Train Loss: 0.6345, Test Loss: 0.6623
# Epoch [222/500], Train Loss: 0.5733, Test Loss: 0.6155
# Epoch [223/500], Train Loss: 0.5764, Test Loss: 0.6649
# Epoch [224/500], Train Loss: 0.5787, Test Loss: 0.6036
# Epoch [225/500], Train Loss: 0.5352, Test Loss: 0.6075
# Epoch [226/500], Train Loss: 0.5398, Test Loss: 0.6107
# Epoch [227/500], Train Loss: 0.5354, Test Loss: 0.6137
# Epoch [228/500], Train Loss: 0.5333, Test Loss: 0.6059
# Epoch [229/500], Train Loss: 0.5300, Test Loss: 0.6068
# Epoch [230/500], Train Loss: 0.6110, Test Loss: 0.6296
# Epoch [231/500], Train Loss: 0.5739, Test Loss: 0.8152
# Epoch [232/500], Train Loss: 0.6804, Test Loss: 0.6398
# Epoch [233/500], Train Loss: 0.5508, Test Loss: 0.6641
# Epoch [234/500], Train Loss: 0.5445, Test Loss: 0.5933
# Epoch [235/500], Train Loss: 0.5166, Test Loss: 0.5802
# Epoch [236/500], Train Loss: 0.5136, Test Loss: 0.5752
# Epoch [237/500], Train Loss: 0.5201, Test Loss: 0.5549
# Epoch [238/500], Train Loss: 0.5068, Test Loss: 0.5439
# Epoch [239/500], Train Loss: 0.5073, Test Loss: 0.6306
# Epoch [240/500], Train Loss: 0.5453, Test Loss: 0.5677
# Epoch [241/500], Train Loss: 0.5354, Test Loss: 0.5275
# Epoch [242/500], Train Loss: 0.4891, Test Loss: 0.5154
# Epoch [243/500], Train Loss: 0.5006, Test Loss: 0.5092
# Epoch [244/500], Train Loss: 0.4852, Test Loss: 0.5059
# Epoch [245/500], Train Loss: 0.4733, Test Loss: 0.5036
# Epoch [246/500], Train Loss: 0.5340, Test Loss: 0.5887
# Epoch [247/500], Train Loss: 0.7460, Test Loss: 0.6318
# Epoch [248/500], Train Loss: 0.6262, Test Loss: 0.5015
# Epoch [249/500], Train Loss: 0.4808, Test Loss: 0.4966
# Epoch [250/500], Train Loss: 0.4650, Test Loss: 0.5031
# Epoch [251/500], Train Loss: 0.4817, Test Loss: 0.5182
# Epoch [252/500], Train Loss: 0.4628, Test Loss: 0.4908
# Epoch [253/500], Train Loss: 0.4454, Test Loss: 0.4820
# Epoch [254/500], Train Loss: 0.4421, Test Loss: 0.4831
# Epoch [255/500], Train Loss: 0.4470, Test Loss: 0.4789
# Epoch [256/500], Train Loss: 0.4491, Test Loss: 0.5001
# Epoch [257/500], Train Loss: 0.4830, Test Loss: 0.6979
# Epoch [258/500], Train Loss: 0.5916, Test Loss: 0.5868
# Epoch [259/500], Train Loss: 0.4547, Test Loss: 0.4772
# Epoch [260/500], Train Loss: 0.4314, Test Loss: 0.4685
# Epoch [261/500], Train Loss: 0.4347, Test Loss: 0.4686
# Epoch [262/500], Train Loss: 0.4329, Test Loss: 0.4611
# Epoch [263/500], Train Loss: 0.4327, Test Loss: 0.4643
# Epoch [264/500], Train Loss: 0.4544, Test Loss: 0.4824
# Epoch [265/500], Train Loss: 0.4313, Test Loss: 0.4929
# Epoch [266/500], Train Loss: 0.4305, Test Loss: 0.4524
# Epoch [267/500], Train Loss: 0.4344, Test Loss: 0.4734
# Epoch [268/500], Train Loss: 0.4494, Test Loss: 0.4922
# Epoch [269/500], Train Loss: 0.4315, Test Loss: 0.4844
# Epoch [270/500], Train Loss: 0.4358, Test Loss: 0.4532
# Epoch [271/500], Train Loss: 0.4681, Test Loss: 0.4713
# Epoch [272/500], Train Loss: 0.4453, Test Loss: 0.4572
# Epoch [273/500], Train Loss: 0.4234, Test Loss: 0.4585
# Epoch [274/500], Train Loss: 0.4035, Test Loss: 0.4346
# Epoch [275/500], Train Loss: 0.4068, Test Loss: 0.4391
# Epoch [276/500], Train Loss: 0.4097, Test Loss: 0.4328
# Epoch [277/500], Train Loss: 0.4006, Test Loss: 0.4371
# Epoch [278/500], Train Loss: 0.4078, Test Loss: 0.4250
# Epoch [279/500], Train Loss: 0.4005, Test Loss: 0.4422
# Epoch [280/500], Train Loss: 0.4246, Test Loss: 0.4529
# Epoch [281/500], Train Loss: 0.4035, Test Loss: 0.4215
# Epoch [282/500], Train Loss: 0.3943, Test Loss: 0.4252
# Epoch [283/500], Train Loss: 0.3933, Test Loss: 0.4593
# Epoch [284/500], Train Loss: 0.4053, Test Loss: 0.4332
# Epoch [285/500], Train Loss: 0.3837, Test Loss: 0.4171
# Epoch [286/500], Train Loss: 0.3809, Test Loss: 0.4181
# Epoch [287/500], Train Loss: 0.3913, Test Loss: 0.4085
# Epoch [288/500], Train Loss: 0.3773, Test Loss: 0.4201
# Epoch [289/500], Train Loss: 0.4017, Test Loss: 0.4182
# Epoch [290/500], Train Loss: 0.3966, Test Loss: 0.4537
# Epoch [291/500], Train Loss: 0.4539, Test Loss: 0.4632
# Epoch [292/500], Train Loss: 0.4421, Test Loss: 0.3990
# Epoch [293/500], Train Loss: 0.3987, Test Loss: 0.3853
# Epoch [294/500], Train Loss: 0.3901, Test Loss: 0.5048
# Epoch [295/500], Train Loss: 0.4481, Test Loss: 0.4564
# Epoch [296/500], Train Loss: 0.4668, Test Loss: 0.4362
# Epoch [297/500], Train Loss: 0.3852, Test Loss: 0.4099
# Epoch [298/500], Train Loss: 0.3744, Test Loss: 0.3887
# Epoch [299/500], Train Loss: 0.3977, Test Loss: 0.5539
# Epoch [300/500], Train Loss: 0.5116, Test Loss: 0.4178
# Epoch [301/500], Train Loss: 0.5663, Test Loss: 0.7602
# Epoch [302/500], Train Loss: 0.5384, Test Loss: 0.4496
# Epoch [303/500], Train Loss: 0.3942, Test Loss: 0.4016
# Epoch [304/500], Train Loss: 0.3716, Test Loss: 0.3694
# Epoch [305/500], Train Loss: 0.4069, Test Loss: 0.3981
# Epoch [306/500], Train Loss: 0.4325, Test Loss: 0.5261
# Epoch [307/500], Train Loss: 0.4465, Test Loss: 0.5121
# Epoch [308/500], Train Loss: 0.4083, Test Loss: 0.3910
# Epoch [309/500], Train Loss: 0.3597, Test Loss: 0.3578
# Epoch [310/500], Train Loss: 0.3438, Test Loss: 0.3568
# Epoch [311/500], Train Loss: 0.3470, Test Loss: 0.3519
# Epoch [312/500], Train Loss: 0.3448, Test Loss: 0.3572
# Epoch [313/500], Train Loss: 0.3449, Test Loss: 0.3511
# Epoch [314/500], Train Loss: 0.3434, Test Loss: 0.3491
# Epoch [315/500], Train Loss: 0.3405, Test Loss: 0.3532
# Epoch [316/500], Train Loss: 0.3441, Test Loss: 0.3433
# Epoch [317/500], Train Loss: 0.3327, Test Loss: 0.3424
# Epoch [318/500], Train Loss: 0.3331, Test Loss: 0.3623
# Epoch [319/500], Train Loss: 0.3432, Test Loss: 0.3388
# Epoch [320/500], Train Loss: 0.3563, Test Loss: 0.3379
# Epoch [321/500], Train Loss: 0.3984, Test Loss: 0.3536
# Epoch [322/500], Train Loss: 0.3845, Test Loss: 0.3999
# Epoch [323/500], Train Loss: 0.3930, Test Loss: 0.3354
# Epoch [324/500], Train Loss: 0.3290, Test Loss: 0.3435
# Epoch [325/500], Train Loss: 0.3278, Test Loss: 0.3309
# Epoch [326/500], Train Loss: 0.3227, Test Loss: 0.3461
# Epoch [327/500], Train Loss: 0.3117, Test Loss: 0.3366
# Epoch [328/500], Train Loss: 0.3220, Test Loss: 0.3421
# Epoch [329/500], Train Loss: 0.3102, Test Loss: 0.3265
# Epoch [330/500], Train Loss: 0.3408, Test Loss: 0.3400
# Epoch [331/500], Train Loss: 0.3764, Test Loss: 0.3326
# Epoch [332/500], Train Loss: 0.3388, Test Loss: 0.3426
# Epoch [333/500], Train Loss: 0.3280, Test Loss: 0.3465
# Epoch [334/500], Train Loss: 0.4181, Test Loss: 0.6173
# Epoch [335/500], Train Loss: 0.5186, Test Loss: 0.6515
# Epoch [336/500], Train Loss: 0.4563, Test Loss: 0.3989
# Epoch [337/500], Train Loss: 0.3418, Test Loss: 0.3787
# Epoch [338/500], Train Loss: 0.3501, Test Loss: 0.3215
# Epoch [339/500], Train Loss: 0.3223, Test Loss: 0.3258
# Epoch [340/500], Train Loss: 0.3199, Test Loss: 0.3147
# Epoch [341/500], Train Loss: 0.3039, Test Loss: 0.3133
# Epoch [342/500], Train Loss: 0.3301, Test Loss: 0.3910
# Epoch [343/500], Train Loss: 0.3888, Test Loss: 0.3126
# Epoch [344/500], Train Loss: 0.3903, Test Loss: 0.3558
# Epoch [345/500], Train Loss: 0.3248, Test Loss: 0.3074
# Epoch [346/500], Train Loss: 0.3232, Test Loss: 0.3188
# Epoch [347/500], Train Loss: 0.3036, Test Loss: 0.3168
# Epoch [348/500], Train Loss: 0.3096, Test Loss: 0.3102
# Epoch [349/500], Train Loss: 0.2944, Test Loss: 0.3104
# Epoch [350/500], Train Loss: 0.3054, Test Loss: 0.3093
# Epoch [351/500], Train Loss: 0.3136, Test Loss: 0.3006
# Epoch [352/500], Train Loss: 0.2892, Test Loss: 0.3012
# Epoch [353/500], Train Loss: 0.3322, Test Loss: 0.3428
# Epoch [354/500], Train Loss: 0.3300, Test Loss: 0.3114
# Epoch [355/500], Train Loss: 0.3092, Test Loss: 0.3272
# Epoch [356/500], Train Loss: 0.3359, Test Loss: 0.3324
# Epoch [357/500], Train Loss: 0.4369, Test Loss: 0.6659
# Epoch [358/500], Train Loss: 0.4414, Test Loss: 0.5224
# Epoch [359/500], Train Loss: 0.3917, Test Loss: 0.3273
# Epoch [360/500], Train Loss: 0.3471, Test Loss: 0.3585
# Epoch [361/500], Train Loss: 0.3215, Test Loss: 0.3601
# Epoch [362/500], Train Loss: 0.3427, Test Loss: 0.3012
# Epoch [363/500], Train Loss: 0.3176, Test Loss: 0.3310
# Epoch [364/500], Train Loss: 0.3212, Test Loss: 0.3094
# Epoch [365/500], Train Loss: 0.2950, Test Loss: 0.3091
# Epoch [366/500], Train Loss: 0.2977, Test Loss: 0.2928
# Epoch [367/500], Train Loss: 0.2871, Test Loss: 0.2880
# Epoch [368/500], Train Loss: 0.2908, Test Loss: 0.2957
# Epoch [369/500], Train Loss: 0.3047, Test Loss: 0.3011
# Epoch [370/500], Train Loss: 0.2955, Test Loss: 0.2940
# Epoch [371/500], Train Loss: 0.2965, Test Loss: 0.3185
# Epoch [372/500], Train Loss: 0.3137, Test Loss: 0.3171
# Epoch [373/500], Train Loss: 0.3179, Test Loss: 0.2826
# Epoch [374/500], Train Loss: 0.3061, Test Loss: 0.2803
# Epoch [375/500], Train Loss: 0.2790, Test Loss: 0.2957
# Epoch [376/500], Train Loss: 0.2796, Test Loss: 0.2868
# Epoch [377/500], Train Loss: 0.2847, Test Loss: 0.3158
# Epoch [378/500], Train Loss: 0.3450, Test Loss: 0.2979
# Epoch [379/500], Train Loss: 0.3054, Test Loss: 0.3152
# Epoch [380/500], Train Loss: 0.2908, Test Loss: 0.2906
# Epoch [381/500], Train Loss: 0.3072, Test Loss: 0.3029
# Epoch [382/500], Train Loss: 0.3181, Test Loss: 0.3153
# Epoch [383/500], Train Loss: 0.3073, Test Loss: 0.3729
# Epoch [384/500], Train Loss: 0.4833, Test Loss: 0.5091
# Epoch [385/500], Train Loss: 0.3499, Test Loss: 0.2752
# Epoch [386/500], Train Loss: 0.2793, Test Loss: 0.2690
# Epoch [387/500], Train Loss: 0.3113, Test Loss: 0.3366
# Epoch [388/500], Train Loss: 0.2978, Test Loss: 0.2898
# Epoch [389/500], Train Loss: 0.2856, Test Loss: 0.2859
# Epoch [390/500], Train Loss: 0.2793, Test Loss: 0.3010
# Epoch [391/500], Train Loss: 0.2837, Test Loss: 0.2775
# Epoch [392/500], Train Loss: 0.3069, Test Loss: 0.3254
# Epoch [393/500], Train Loss: 0.2970, Test Loss: 0.2645
# Epoch [394/500], Train Loss: 0.2786, Test Loss: 0.2620
# Epoch [395/500], Train Loss: 0.2687, Test Loss: 0.2720
# Epoch [396/500], Train Loss: 0.2744, Test Loss: 0.3096
# Epoch [397/500], Train Loss: 0.3789, Test Loss: 0.3906
# Epoch [398/500], Train Loss: 0.4648, Test Loss: 0.3455
# Epoch [399/500], Train Loss: 0.2879, Test Loss: 0.2621
# Epoch [400/500], Train Loss: 0.2826, Test Loss: 0.2675
# Epoch [401/500], Train Loss: 0.2900, Test Loss: 0.3219
# Epoch [402/500], Train Loss: 0.4111, Test Loss: 0.2657
# Epoch [403/500], Train Loss: 0.3126, Test Loss: 0.2797
# Epoch [404/500], Train Loss: 0.2672, Test Loss: 0.2660
# Epoch [405/500], Train Loss: 0.2996, Test Loss: 0.2669
# Epoch [406/500], Train Loss: 0.2916, Test Loss: 0.4025
# Epoch [407/500], Train Loss: 0.3165, Test Loss: 0.2757
# Epoch [408/500], Train Loss: 0.3166, Test Loss: 0.2758
# Epoch [409/500], Train Loss: 0.3037, Test Loss: 0.2955
# Epoch [410/500], Train Loss: 0.2740, Test Loss: 0.2522
# Epoch [411/500], Train Loss: 0.2691, Test Loss: 0.2492
# Epoch [412/500], Train Loss: 0.2617, Test Loss: 0.2554
# Epoch [413/500], Train Loss: 0.2576, Test Loss: 0.2484
# Epoch [414/500], Train Loss: 0.2540, Test Loss: 0.2526
# Epoch [415/500], Train Loss: 0.2539, Test Loss: 0.2543
# Epoch [416/500], Train Loss: 0.2536, Test Loss: 0.2571
# Epoch [417/500], Train Loss: 0.2967, Test Loss: 0.3230
# Epoch [418/500], Train Loss: 0.3505, Test Loss: 0.4431
# Epoch [419/500], Train Loss: 0.3222, Test Loss: 0.2450
# Epoch [420/500], Train Loss: 0.2510, Test Loss: 0.2437
# Epoch [421/500], Train Loss: 0.2380, Test Loss: 0.2522
# Epoch [422/500], Train Loss: 0.2451, Test Loss: 0.2446
# Epoch [423/500], Train Loss: 0.2736, Test Loss: 0.4566
# Epoch [424/500], Train Loss: 0.3340, Test Loss: 0.2408
# Epoch [425/500], Train Loss: 0.2474, Test Loss: 0.2609
# Epoch [426/500], Train Loss: 0.2681, Test Loss: 0.2577
# Epoch [427/500], Train Loss: 0.2434, Test Loss: 0.2391
# Epoch [428/500], Train Loss: 0.2369, Test Loss: 0.2374
# Epoch [429/500], Train Loss: 0.3206, Test Loss: 0.2501
# Epoch [430/500], Train Loss: 0.3687, Test Loss: 0.3955
# Epoch [431/500], Train Loss: 0.2897, Test Loss: 0.2604
# Epoch [432/500], Train Loss: 0.2689, Test Loss: 0.2402
# Epoch [433/500], Train Loss: 0.2601, Test Loss: 0.2624
# Epoch [434/500], Train Loss: 0.2559, Test Loss: 0.2633
# Epoch [435/500], Train Loss: 0.2467, Test Loss: 0.2366
# Epoch [436/500], Train Loss: 0.2502, Test Loss: 0.2568
# Epoch [437/500], Train Loss: 0.2430, Test Loss: 0.2470
# Epoch [438/500], Train Loss: 0.2470, Test Loss: 0.2493
# Epoch [439/500], Train Loss: 0.2683, Test Loss: 0.2330
# Epoch [440/500], Train Loss: 0.2619, Test Loss: 0.2548
# Epoch [441/500], Train Loss: 0.2347, Test Loss: 0.2314
# Epoch [442/500], Train Loss: 0.2458, Test Loss: 0.2452
# Epoch [443/500], Train Loss: 0.2529, Test Loss: 0.2329
# Epoch [444/500], Train Loss: 0.2621, Test Loss: 0.2778
# Epoch [445/500], Train Loss: 0.2584, Test Loss: 0.2868
# Epoch [446/500], Train Loss: 0.2577, Test Loss: 0.2375
# Epoch [447/500], Train Loss: 0.2426, Test Loss: 0.2341
# Epoch [448/500], Train Loss: 0.2394, Test Loss: 0.2367
# Epoch [449/500], Train Loss: 0.2543, Test Loss: 0.2281
# Epoch [450/500], Train Loss: 0.2392, Test Loss: 0.2573
# Epoch [451/500], Train Loss: 0.2734, Test Loss: 0.2420
# Epoch [452/500], Train Loss: 0.2538, Test Loss: 0.3024
# Epoch [453/500], Train Loss: 0.2446, Test Loss: 0.2270
# Epoch [454/500], Train Loss: 0.2297, Test Loss: 0.2351
# Epoch [455/500], Train Loss: 0.2330, Test Loss: 0.2884
# Epoch [456/500], Train Loss: 0.2915, Test Loss: 0.5240
# Epoch [457/500], Train Loss: 0.3708, Test Loss: 0.2777
# Epoch [458/500], Train Loss: 0.2997, Test Loss: 0.3873
# Epoch [459/500], Train Loss: 0.3934, Test Loss: 0.2368
# Epoch [460/500], Train Loss: 0.5054, Test Loss: 0.4191
# Epoch [461/500], Train Loss: 0.2945, Test Loss: 0.2739
# Epoch [462/500], Train Loss: 0.2646, Test Loss: 0.2696
# Epoch [463/500], Train Loss: 0.2404, Test Loss: 0.2465
# Epoch [464/500], Train Loss: 0.2344, Test Loss: 0.2270
# Epoch [465/500], Train Loss: 0.2410, Test Loss: 0.2236
# Epoch [466/500], Train Loss: 0.2320, Test Loss: 0.2359
# Epoch [467/500], Train Loss: 0.2320, Test Loss: 0.2197
# Epoch [468/500], Train Loss: 0.2354, Test Loss: 0.2395
# Epoch [469/500], Train Loss: 0.2361, Test Loss: 0.2364
# Epoch [470/500], Train Loss: 0.2432, Test Loss: 0.2995
# Epoch [471/500], Train Loss: 0.2450, Test Loss: 0.2416
# Epoch [472/500], Train Loss: 0.2410, Test Loss: 0.2350
# Epoch [473/500], Train Loss: 0.2719, Test Loss: 0.2557
# Epoch [474/500], Train Loss: 0.2668, Test Loss: 0.3819
# Epoch [475/500], Train Loss: 0.2717, Test Loss: 0.3177
# Epoch [476/500], Train Loss: 0.3697, Test Loss: 0.3410
# Epoch [477/500], Train Loss: 0.3305, Test Loss: 0.2616
# Epoch [478/500], Train Loss: 0.3053, Test Loss: 0.3324
# Epoch [479/500], Train Loss: 0.3219, Test Loss: 0.3485
# Epoch [480/500], Train Loss: 0.2629, Test Loss: 0.2642
# Epoch [481/500], Train Loss: 0.2343, Test Loss: 0.2222
# Epoch [482/500], Train Loss: 0.2347, Test Loss: 0.2452
# Epoch [483/500], Train Loss: 0.2210, Test Loss: 0.2105
# Epoch [484/500], Train Loss: 0.2179, Test Loss: 0.2150
# Epoch [485/500], Train Loss: 0.2244, Test Loss: 0.2090
# Epoch [486/500], Train Loss: 0.2176, Test Loss: 0.2101
# Epoch [487/500], Train Loss: 0.2228, Test Loss: 0.3072
# Epoch [488/500], Train Loss: 0.2661, Test Loss: 0.3226
# Epoch [489/500], Train Loss: 0.2807, Test Loss: 0.2227
# Epoch [490/500], Train Loss: 0.2319, Test Loss: 0.2578
# Epoch [491/500], Train Loss: 0.2684, Test Loss: 0.2123
# Epoch [492/500], Train Loss: 0.2374, Test Loss: 0.2658
# Epoch [493/500], Train Loss: 0.2399, Test Loss: 0.2271
# Epoch [494/500], Train Loss: 0.2946, Test Loss: 0.2896
# Epoch [495/500], Train Loss: 0.2556, Test Loss: 0.2091
# Epoch [496/500], Train Loss: 0.2241, Test Loss: 0.2236
# Epoch [497/500], Train Loss: 0.2262, Test Loss: 0.2140
# Epoch [498/500], Train Loss: 0.2299, Test Loss: 0.2174
# Epoch [499/500], Train Loss: 0.2229, Test Loss: 0.2162
# Epoch [500/500], Train Loss: 0.2160, Test Loss: 0.2096
# Training finished for firstst derivative

# %%
plot_heatmaps(L3ModelK9_trained)

# %% [markdown]
# ### Compute frequencies of derivatives

# %%
def compute_fft_and_max_freq(dataloader, deriv=False, model=None):
    fft_amplitudes = []
    max_frequencies = []
    T = 2 * torch.pi
    N = 1000

    # Calculate frequencies for the FFT
    frequencies = torch.fft.fftfreq(N, T / (2 * torch.pi * N))
    positive_freq_indices = frequencies >= 0
    positive_freqs = frequencies[positive_freq_indices]

    # Iterate over each batch
    for functions, derivatives in dataloader:  # Note that derivatives are ignored in this loop
        
        if deriv and not model:
            functions = derivatives
            
        if model:
            functions = model(functions.unsqueeze(1)).squeeze()
            # output = model(functions)
            
            # output = output.squeeze()
            # functions = output # set this so that the FFTs can be computed in the next line
        
        # Compute FFT using PyTorch
        F = torch.fft.fft(functions)
        magnitudes = torch.abs(F) / N

        # Consider only positive frequencies
        positive_magnitudes = magnitudes[:, positive_freq_indices]

        fft_amplitudes.append(positive_magnitudes)
        
        # Maximum frequency based on the highest amplitude for each function in the batch
        max_indices = torch.argmax(positive_magnitudes, dim=1)
        batch_max_freqs = positive_freqs[max_indices]
        max_frequencies.extend(batch_max_freqs)

    return torch.vstack(fft_amplitudes), torch.tensor(max_frequencies), positive_freqs

def plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type, xmin=0, xmax=0):
    fft_amplitudes = fft_amplitudes.detach().numpy()
    max_frequencies = max_frequencies.detach().numpy()
    freqs = freqs.detach().numpy()
    
    # Sort functions by the maximum frequency
    sorted_indices = np.argsort(-max_frequencies)  # Sort in descending order
    sorted_fft = fft_amplitudes[sorted_indices]

    plt.figure(figsize=(10, 6))
    im = plt.imshow(sorted_fft, aspect='auto', extent=[freqs[0], freqs[-1], 0, len(sorted_fft)])
    plt.colorbar(im, label='Amplitude')
    plt.xlabel('Frequency (rad/s)')
    plt.ylabel('Function Index (sorted by max frequency)')
    plt.title(f'FFT Amplitude Heatmap for {fun_type}')
    plt.xlim([xmin, xmax])
    plt.show()

# %%
def plot_heatmaps(model=None, deriv=None):
    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_dataloader,\
        deriv=deriv, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='Low freq model outputs', xmin=0, xmax=6)

    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(general_freq_dataloader,\
        deriv=deriv, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='General freq model outputs', xmin=0, xmax=16)

    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(high_freq_dataloader,\
        deriv=deriv, model=model)
    plot_heatmap(fft_amplitudes, max_frequencies, freqs, fun_type='High freq model outputs', xmin=10, xmax=16)

# %%
plot_heatmaps(deriv=True)

# %%
def plot_heatmaps_residue(model=None, deriv=None):

    # low freq
    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(low_freq_dataloader,\
        deriv=deriv, model=None)
    fft_amplitudes_model, max_frequencies_model, freqs_model = compute_fft_and_max_freq(low_freq_dataloader,\
        deriv=None, model=model)

    fft_amplitudes_res = fft_amplitudes - fft_amplitudes_model
    max_frequencies_res = max_frequencies - max_frequencies_model
    freqs_res = freqs - freqs_model

    plot_heatmap(fft_amplitudes_res, max_frequencies_res, freqs_res, fun_type='Low freq residues')

    # general freq
    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(general_freq_dataloader,\
        deriv=deriv, model=None)
    fft_amplitudes_model, max_frequencies_model, freqs_model = compute_fft_and_max_freq(general_freq_dataloader,\
        deriv=None, model=model)

    fft_amplitudes_res = fft_amplitudes - fft_amplitudes_model
    max_frequencies_res = max_frequencies - max_frequencies_model
    freqs_res = freqs - freqs_model

    plot_heatmap(fft_amplitudes_res, max_frequencies_res, freqs_res, fun_type='General freq residues', xmin=0, xmax=16)

    # high freq
    fft_amplitudes, max_frequencies, freqs = compute_fft_and_max_freq(high_freq_dataloader,\
        deriv=deriv, model=None)
    fft_amplitudes_model, max_frequencies_model, freqs_model = compute_fft_and_max_freq(high_freq_dataloader,\
        deriv=None, model=model)

    fft_amplitudes_res = fft_amplitudes - fft_amplitudes_model
    max_frequencies_res = max_frequencies - max_frequencies_model
    freqs_res = freqs - freqs_model

    plot_heatmap(fft_amplitudes_res, max_frequencies_res, freqs_res, fun_type='High freq residues', xmin=10, xmax=6)

# %%
plot_heatmaps_residue(model=L3ModelK9_trained, deriv=True)
# Out:
# /tmp/ipykernel_719487/1328119954.py:51: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   im = plt.imshow(sorted_fft, aspect='auto', extent=[freqs[0], freqs[-1], 0, len(sorted_fft)])
# /tmp/ipykernel_719487/1328119954.py:56: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   plt.xlim([xmin, xmax])
